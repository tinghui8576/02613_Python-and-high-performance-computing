# %%
import pandas as pd
import matplotlib.pyplot as plt
time = pd.read_csv('time.csv')

plt.scatter(time['core'], time['user'])
plt.scatter(time['core'], time['sys'])
plt.scatter(time['core'], time['real'])
plt.xlabel('Threads')
plt.ylabel('Time(s)')
# Out:
# Text(0, 0.5, 'Time(s)')
