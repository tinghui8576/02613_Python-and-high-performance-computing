# %% [markdown]
# # 04 comparing row and col

# %%
10.0,194.90603335181527,185.38009183900706
23.263050671536263,762.7058469803984,1103.8440215008557
54.116952654646376,1157.6141715114484,1402.2882279288208
125.89254117941661,1616.485566449229,1744.4801820967348
292.8644564625237,1964.9556427291514,1959.4289575880277
681.2920690579608,1745.085747430302,1746.5774638549415
1584.8931924611124,1727.7274954603288,1667.3716297846588
3686.9450645195734,1640.9342580153514,1641.533561413196
8576.958985908937,1567.8539964241406,1522.8857040698606

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("content.csv")
plt.loglog(df['SIZE'],df['row'], label ='row')
plt.loglog(df['SIZE'],df['col'], label ='col')
plt.legend()
plt.show()
plt.scatter(df['SIZE'],df['row'], label ='row')
plt.scatter(df['SIZE'],df['col'], label ='col')
plt.legend()

# %% [markdown]
# # 06 comparing row on its own

# %%
100.0 ,4.12239371286692   99.68521272916749
464.15888336127773 , 427.88129328625246 
2154.4346900318824 ,1551.2753727181996 
10000.0  ,3882.120125552065   3928.817603505465
46415.888336127726, 5664.261794591361   5838.147463461373
215443.46900318822 , 6403.626659412716   6476.21240542733
1000000.0 ,6203.9674869183045   6295.23443782526
4641588.833612773   5927.751963645313   5947.300279304266
21544346.900318824   6022.818016825863   6050.88926

# %%
import numpy as np
SIZE = 35
mat = np.random.rand(int(SIZE), SIZE)
print(mat.nbytes)
mat = np.random.randint(0, 256, size=(int(SIZE), int(SIZE)), dtype=np.uint8)
print(mat.nbytes)

232701096
62370916
# Out:
# 9800
# 1225

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("row_comparing.csv")

plt.scatter(df['SIZE'],df['row'])
plt.show()
plt.loglog(df['SIZE'],df['row'])
